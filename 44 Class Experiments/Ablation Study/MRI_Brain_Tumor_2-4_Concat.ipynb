# %%
import os
import itertools

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout,BatchNormalization

import warnings
warnings.filterwarnings('ignore')

print("Modules Loaded")
# Out:
# Modules Loaded

# %%
import os
import cv2
import glob
import math
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import multiprocessing
import tensorflow as tf
from pathlib import Path
import concurrent.futures
import keras.backend as K
from time import perf_counter
from functools import lru_cache
import matplotlib.pyplot as plt
from keras import layers, models
from keras.optimizers import Adam
from PIL import Image, ImageEnhance
from joblib import Parallel, delayed
from collections import defaultdict, Counter
from sklearn.preprocessing import LabelEncoder
from keras.metrics import Precision, Recall, AUC
from keras.callbacks import LearningRateScheduler
from keras.utils import plot_model, to_categorical
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from concurrent.futures import ThreadPoolExecutor, as_completed
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Read data and store in df

# %%
def main(train_data_path):
    
    """
    return training and testing dataframes including 2 columns image path and its label
    
    Args:
      train_data_path (string): string includes your train data path
      test_data_path (string): string includes your test data path
      note: data_path argument must contains your classes dirs
      
    Returns:
      train_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the training images and the label of each image
      test_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the testing images and the label of each image

    """
    
    for dirs in [train_data_path]:

        filepaths = []
        labels = []
        classes_list = sorted(os.listdir(dirs))

        filepaths,labels = get_fileList(classes_list, dirs, filepaths, labels)
        
        train_df = obtain_train_df(filepaths, labels)
        
            
    return train_df



def get_fileList(classes_list, dirs, filepaths, labels):
    
    
    """
    return file paths list including all full image paths and label for each one
    
    Args:
      classes_list (list): list includes name of classes dirs
      dirs (string): the data path
      filepaths (list): empty list to fill with images paths later
      labels (list): empty list to fill with each image label later
      
    Returns:
      count (scalar):  number of images in your dataset
    """
    
    
    for s_class in classes_list:
        
        label = s_class
        classpath = os.path.join(dirs, s_class)
        flist = sorted(os.listdir(classpath))
        
        store_image_names_and_its_labels(flist, classpath, filepaths, labels, label)
        
    return filepaths, labels


def store_image_names_and_its_labels(flist, classpath, filepaths, labels, label):
    
    """
    return nothing, it fills the filepaths list with all the images paths and its labels
    
    Args:
      flist (list) : contains all the image names in certain class
      classes_list (list): list includes name of classes dirs
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset
      label (string): label for a specific image
      
    Returns:
      nothing
    """
    
    
    for file in flist:
        file_path = os.path.join(classpath, file)
        filepaths.append(file_path)
        labels.append(label)



def obtain_train_df(filepaths, labels):
    
    """
    Return Dataframe with 2 columns contains each image path with its label
    
    Args:
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset
      
    Returns:
      train_df (DataFrame):  Dataframe with 2 columns contains each image path with its label
    """
    
    train_df =pd.DataFrame({
        'image_path' : filepaths,
        'label' : labels
    })
    return train_df

# %%
data_dir = "D://xtras//CNN//Brain Tumor//Dataset - 44 classes"

data_df = main(data_dir)

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data_df.head()
# Out:
#                                           image_path           label
# 0  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...  Astrocitoma T1
# 1  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...  Astrocitoma T1
# 2  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...  Astrocitoma T1
# 3  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...  Astrocitoma T1
# 4  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...  Astrocitoma T1

# %%
num_classes = len(data_df['label'].unique())
print(f"We have {num_classes} classes")
print(f"We have {data_df.shape[0]} images")
# Out:
# We have 44 classes
# We have 4479 images

# %%
num_classes = len(data_df['label'].value_counts())
data_df['label'].value_counts()
df = data_df

# %% [markdown]
# #### Split data into train, valid, test

# %%
train_df, test_df = train_test_split(df, train_size=0.8, random_state=42, stratify=df['label'])

train_df, valid_df = train_test_split(train_df, train_size=0.8, random_state=42, stratify=train_df['label'])

# %%
print(f"Train shape: {train_df.shape}")
print(f"Validation shape: {valid_df.shape}")
print(f"Test shape: {test_df.shape}")
# Out:
# Train shape: (2866, 2)
# Validation shape: (717, 2)
# Test shape: (896, 2)

# %%
train_df
# Out:
#                                              image_path             label
# 2760  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...  Neurocitoma T1C+
# 4306  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...        _NORMAL T2
# 4124  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...        _NORMAL T1
# 211   D://xtras//CNN//Brain Tumor//Dataset - 44 clas...  Astrocitoma T1C+
# 2870  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...    Neurocitoma T2
# ...                                                 ...               ...
# 1857  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...   Meningioma T1C+
# 3381  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...     Schwannoma T1
# 1296  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...   Glioblastoma T2
# 4447  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...        _NORMAL T2
# 1358  D://xtras//CNN//Brain Tumor//Dataset - 44 clas...      Granuloma T1
#
# [2866 rows x 2 columns]

# %% [markdown]
# #### ImageDataGenerator

# %%
BATCH_SIZE = 8
image_size = (224, 224)

gen = ImageDataGenerator()

train_gen = gen.flow_from_dataframe(train_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
train_steps = len(train_df) // BATCH_SIZE

valid_gen = gen.flow_from_dataframe(valid_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
val_steps = len(valid_df) // BATCH_SIZE

test_gen = gen.flow_from_dataframe(test_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
test_steps = len(test_df) // BATCH_SIZE
# Out:
# Found 2866 validated image filenames belonging to 44 classes.
# Found 717 validated image filenames belonging to 44 classes.
# Found 895 validated image filenames belonging to 44 classes.

# %% [markdown]
# ### Model Structure

# %%
class AvgTwiceMaxPooling2D(layers.Layer):
    """
    Custom Keras layer that performs average - twice-maximum pooling on the input.

    Args:
        pool_size (int, optional): Pooling window size. Defaults to 2.
        strides (int, optional): Stride size for pooling. Defaults to 2.
        padding (str, optional): Padding mode ('same' or 'valid'). Defaults to 'same'.

    Returns:
        tf.Tensor: Output tensor after applying twice-maximum average pooling.
    """
    def __init__(self, pool_size=2, strides=2, padding='same', **kwargs):
        super(AvgTwiceMaxPooling2D, self).__init__(**kwargs)
        self.pool_size = pool_size
        self.strides = strides
        self.padding = padding

    @tf.function
    def call(self, inputs, **kwargs):
        """
        Apply the average - twice-maximum pooling operation to the input tensor.

        Args:
            inputs (tf.Tensor): Input tensor.

        Returns:
            tf.Tensor: Output tensor after applying twice-maximum average pooling.
            :param **kwargs:
        """
        # Apply max pooling and average pooling
        max_pooled = layers.MaxPooling2D(pool_size=self.pool_size, strides=self.strides, padding=self.padding)(inputs)
        avg_pooled = layers.AveragePooling2D(pool_size=self.pool_size, strides=self.strides, padding=self.padding)(inputs)

        # Apply the average - twice-maximum pooling operation
        output = tf.subtract(avg_pooled, tf.add(max_pooled, max_pooled))
        return output

# %%
from tensorflow.keras.layers import LeakyReLU
def create_brian_tumor_model(input_shape, n_classes):
    """
    Create a convolutional neural network model optimized for image classification.

    Args:
        input_shape (tuple): Shape of input images (height, width, channels).
        n_classes (int): Number of classes for classification.

    Returns:
        tf.keras.Model: Created CNN model.
    """
    model_name = 'MRINet'

    input_layer = layers.Input(shape=input_shape, name='Input')

    blk1 = layers.Conv2D(21, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv1')(input_layer)
    blk1 = layers.BatchNormalization()(blk1)
    blk1 = layers.MaxPooling2D(strides=2, name='MaxPool1')(blk1)

    blk2 = layers.Conv2D(34, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv2')(blk1)
    blk2 = layers.BatchNormalization()(blk2)
    blk2 = layers.MaxPooling2D(strides=2, name='MaxPool2')(blk2)

    avgtwicemax = AvgTwiceMaxPooling2D(pool_size=(3, 3))(blk2)

    blk3 = layers.Conv2D(55, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv3')(blk2)
    blk3 = layers.MaxPooling2D(strides=2, name='MaxPool3')(blk3) 
    norm = layers.BatchNormalization()(blk3) 

    concat = layers.Concatenate(name="VerticalConcat2")([norm, avgtwicemax])

    # concat from 3 to 5
    # blk = layers.Conv2D(24, kernel_size=3, strides=1, padding='same', activation='relu', name='ConvC')(norm)
    # blk = layers.BatchNormalization()(blk)
    # blk = AvgTwiceMaxPooling2D(pool_size=(3, 3))(blk)


    blk4 = layers.Conv2D(89, kernel_size=3, padding='same', activation='relu', name='Conv4')(concat)
    blk4 = layers.BatchNormalization()(blk4) 
    blk4 = layers.MaxPooling2D(strides=2, name='MaxPool4')(blk4)

    # concat2 = layers.Concatenate(name="VerticalConcat3")([blk4, blk])
    # added block 5
    blk5 = layers.Conv2D(144, kernel_size=3, padding='same', activation='relu', name='Conv5')(blk4)
    blk5 = layers.BatchNormalization()(blk5) 
    blk5 = layers.MaxPooling2D(strides=2, name='MaxPool5')(blk5)

    # added block 6
    blk6 = layers.Conv2D(233, kernel_size=3, padding='same',  activation="relu", name='Conv7')(blk5)
    blk6 = layers.DepthwiseConv2D(depth_multiplier=1, kernel_size=(3, 3), padding='same', activation="relu", name='DConv4')(blk6)
    blk6 = layers.BatchNormalization()(blk6) 

    # added block 7
    blk7 = layers.Conv2D(377, kernel_size=3, padding='same',  activation=LeakyReLU(alpha=0.01), name='Conv8')(blk6)
    blk7 = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding='same', activation="relu", name='DConv5')(blk7)
    blk7 = layers.BatchNormalization()(blk7) 

    gap = layers.GlobalAveragePooling2D(name='GAP')(blk7)

    output = layers.Dense(n_classes, activation='softmax', name='Output')(gap)

    model = tf.keras.Model(inputs=input_layer, outputs=output, name=model_name)
    return model

# %%
num_classes
# Out:
# 44

# %%
input_shape = (224, 224, 3)
model = create_brian_tumor_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "MRINet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Input (InputLayer)             [(None, 224, 224, 3  0           []
#                                 )]
#
#  Conv1 (Conv2D)                 (None, 224, 224, 21  588         ['Input[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 224, 224, 21  84         ['Conv1[0][0]']
#  alization)                     )
#
#  MaxPool1 (MaxPooling2D)        (None, 112, 112, 21  0           ['batch_normalization[0][0]']
#                                 )
#
#  Conv2 (Conv2D)                 (None, 112, 112, 34  6460        ['MaxPool1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 34  136        ['Conv2[0][0]']
#  rmalization)                   )
#
#  MaxPool2 (MaxPooling2D)        (None, 56, 56, 34)   0           ['batch_normalization_1[0][0]']
#
#  Conv3 (Conv2D)                 (None, 56, 56, 55)   16885       ['MaxPool2[0][0]']
#
#  MaxPool3 (MaxPooling2D)        (None, 28, 28, 55)   0           ['Conv3[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 28, 28, 55)  220         ['MaxPool3[0][0]']
#  rmalization)
#
#  avg_twice_max_pooling2d (AvgTw  (None, 28, 28, 34)  0           ['MaxPool2[0][0]']
#  iceMaxPooling2D)
#
#  VerticalConcat2 (Concatenate)  (None, 28, 28, 89)   0           ['batch_normalization_2[0][0]',
#                                                                   'avg_twice_max_pooling2d[0][0]']
#
#  Conv4 (Conv2D)                 (None, 28, 28, 89)   71378       ['VerticalConcat2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 89)  356         ['Conv4[0][0]']
#  rmalization)
#
#  MaxPool4 (MaxPooling2D)        (None, 14, 14, 89)   0           ['batch_normalization_3[0][0]']
#
#  Conv5 (Conv2D)                 (None, 14, 14, 144)  115488      ['MaxPool4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 14, 14, 144)  576        ['Conv5[0][0]']
#  rmalization)
#
#  MaxPool5 (MaxPooling2D)        (None, 7, 7, 144)    0           ['batch_normalization_4[0][0]']
#
#  Conv7 (Conv2D)                 (None, 7, 7, 233)    302201      ['MaxPool5[0][0]']
#
#  DConv4 (DepthwiseConv2D)       (None, 7, 7, 233)    2330        ['Conv7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 7, 7, 233)   932         ['DConv4[0][0]']
#  rmalization)
#
#  Conv8 (Conv2D)                 (None, 7, 7, 377)    790946      ['batch_normalization_5[0][0]']
#
#  DConv5 (DepthwiseConv2D)       (None, 7, 7, 754)    7540        ['Conv8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 7, 7, 754)   3016        ['DConv5[0][0]']
#  rmalization)
#
#  GAP (GlobalAveragePooling2D)   (None, 754)          0           ['batch_normalization_6[0][0]']
#
#  Output (Dense)                 (None, 44)           33220       ['GAP[0][0]']
#
# ==================================================================================================
# Total params: 1,352,356
# Trainable params: 1,349,696
# Non-trainable params: 2,660
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
def create_metrics():
    """
    Creates instances of various metrics for evaluating model performance.

    Returns:
        tuple: A tuple of the metrics: (recall, precision, f1_score, auc, sensitivity, specificity, mcc).
    """
    @tf.function
    def f1_score(y_true, y_pred):
        """
        Calculates the F1 score.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: F1 score.
        """
        tp = true_positive(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        precision = tp / (tp + fp + K.epsilon())
        recall = tp / (tp + fn + K.epsilon())

        return 2 * (precision * recall) / (precision + recall + K.epsilon())

    @tf.function
    def specificity(y_true, y_pred):
        """
        Calculates the specificity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Specificity.
        """
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)

        return tn / (tn + fp + K.epsilon())

    @tf.function
    def sensitivity(y_true, y_pred):
        """
        Calculates the sensitivity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Sensitivity.
        """
        tp = true_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        return tp / (tp + fn + K.epsilon())

    @tf.function
    def mcc(y_true, y_pred):
        """
        Calculates the Matthews correlation coefficient (MCC).

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Matthews correlation coefficient.
        """
        tp = true_positive(y_true, y_pred)
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        numerator = (tp * tn - fp * fn)
        denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

        return numerator / (denominator + K.epsilon())

    @tf.function
    def true_positive(y_true, y_pred):
        """
        Calculates the number of true positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true positives.
        """
        y_pred_pos, _, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_pos)

    @tf.function
    def false_positive(y_true, y_pred):
        """
        Calculates the number of false positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false positives.
        """
        y_pred_pos, _, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_pos)

    @tf.function
    def false_negative(y_true, y_pred):
        """
        Calculates the number of false negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false negatives.
        """
        _, y_pred_neg, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_neg)

    @tf.function
    def true_negative(y_true, y_pred):
        """
        Calculates the number of true negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true negatives.
        """
        _, y_pred_neg, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_neg)

    @tf.function
    def calculate_confusion_matrix(y_true, y_pred):
        """
        Calculates the components of the confusion matrix.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            tuple: A tuple containing the components of the confusion matrix: (y_pred_pos, y_pred_neg, y_pos, y_neg).
        """
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.round(K.clip(y_true, 0, 1))
        y_neg = 1 - y_pos
        return y_pred_pos, y_pred_neg, y_pos, y_neg

    precision_metric = Precision()
    recall_metric = Recall()
    f1_score_metric = f1_score
    specificity_metric = specificity
    sensitivity_metric = sensitivity
    mcc_metric = mcc
    auc_metric = AUC()

    return (
        precision_metric,
        recall_metric,
        f1_score_metric,
        specificity_metric,
        sensitivity_metric,
        mcc_metric,
        auc_metric,
    )

# %%
model.compile(
    optimizer = Adam(learning_rate = 5e-4),
    loss = 'categorical_crossentropy',
    metrics = ["accuracy", create_metrics()]
)

# %%
class TimeCallback(tf.keras.callbacks.Callback):
    """Custom callback to record epoch times and total training time."""

    def on_train_begin(self, logs=None):
        """Initialize training start time and epoch times."""
        self.train_start_time = time.perf_counter()
        self.epoch_times = []

    def on_epoch_begin(self, epoch, logs=None):
        """Record start time of each epoch."""
        self.epoch_start_time = time.perf_counter()

    def on_epoch_end(self, epoch, logs=None):
        """Calculate and store epoch time."""
        epoch_time = time.perf_counter() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

    def on_train_end(self, logs=None):
        """Calculate total training time."""
        self.total_train_time = time.perf_counter() - self.train_start_time

# Create an instance of the TimeCallback
time_callback = TimeCallback()

# %%
#@title Learning rate scheduler

from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

def lr_schedule(epoch,lr):
    if epoch < 13:
        return lr
    else:
        return 0.9*lr


lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
TOTAL_EPOCHS = 25

start_time = perf_counter()
history = model.fit(
    train_gen,
    epochs=TOTAL_EPOCHS,
    validation_data=valid_gen,
    steps_per_epoch=train_steps,
    validation_steps=val_steps,
    callbacks=[time_callback,lr_scheduler]
)
end_time = perf_counter()
# Out:
# Epoch 1/25
# 358/358 [==============================] - 65s 164ms/step - loss: 2.4841 - accuracy: 0.3530 - precision: 0.7104 - recall: 0.1193 - f1_score: 0.1802 - specificity: 0.9989 - sensitivity: 0.1191 - mcc: 0.2210 - auc: 0.8851 - val_loss: 2.7840 - val_accuracy: 0.3258 - val_precision: 1.0000 - val_recall: 0.0028 - val_f1_score: 0.0050 - val_specificity: 1.0000 - val_sensitivity: 0.0028 - val_mcc: 0.0079 - val_auc: 0.9136 - lr: 5.0000e-04
# Epoch 2/25
# 358/358 [==============================] - 39s 109ms/step - loss: 1.3709 - accuracy: 0.6221 - precision: 0.8429 - recall: 0.4262 - f1_score: 0.5469 - specificity: 0.9982 - sensitivity: 0.4253 - mcc: 0.5794 - auc: 0.9705 - val_loss: 1.2008 - val_accuracy: 0.6770 - val_precision: 0.8241 - val_recall: 0.4803 - val_f1_score: 0.5939 - val_specificity: 0.9976 - val_sensitivity: 0.4803 - val_mcc: 0.6152 - val_auc: 0.9750 - lr: 5.0000e-04
# Epoch 3/25
# 358/358 [==============================] - 13s 36ms/step - loss: 0.8204 - accuracy: 0.7701 - precision: 0.8953 - recall: 0.6400 - f1_score: 0.7353 - specificity: 0.9983 - sensitivity: 0.6386 - mcc: 0.7459 - auc: 0.9882 - val_loss: 1.1218 - val_accuracy: 0.6966 - val_precision: 0.7599 - val_recall: 0.6180 - val_f1_score: 0.6772 - val_specificity: 0.9955 - val_sensitivity: 0.6180 - val_mcc: 0.6760 - val_auc: 0.9623 - lr: 5.0000e-04
# Epoch 4/25
# 358/358 [==============================] - 15s 42ms/step - loss: 0.4869 - accuracy: 0.8604 - precision: 0.9293 - recall: 0.7862 - f1_score: 0.8458 - specificity: 0.9986 - sensitivity: 0.7846 - mcc: 0.8482 - auc: 0.9961 - val_loss: 0.7854 - val_accuracy: 0.7823 - val_precision: 0.8355 - val_recall: 0.7205 - val_f1_score: 0.7690 - val_specificity: 0.9967 - val_sensitivity: 0.7205 - val_mcc: 0.7679 - val_auc: 0.9806 - lr: 5.0000e-04
# Epoch 5/25
# 358/358 [==============================] - 32s 91ms/step - loss: 0.2693 - accuracy: 0.9265 - precision: 0.9525 - recall: 0.8901 - f1_score: 0.9175 - specificity: 0.9989 - sensitivity: 0.8893 - mcc: 0.9174 - auc: 0.9988 - val_loss: 0.5862 - val_accuracy: 0.8511 - val_precision: 0.8904 - val_recall: 0.8216 - val_f1_score: 0.8523 - val_specificity: 0.9976 - val_sensitivity: 0.8216 - val_mcc: 0.8511 - val_auc: 0.9838 - lr: 5.0000e-04
# Epoch 6/25
# 358/358 [==============================] - 29s 80ms/step - loss: 0.1849 - accuracy: 0.9500 - precision: 0.9660 - recall: 0.9258 - f1_score: 0.9430 - specificity: 0.9992 - sensitivity: 0.9249 - mcc: 0.9427 - auc: 0.9993 - val_loss: 0.7927 - val_accuracy: 0.8076 - val_precision: 0.8532 - val_recall: 0.7753 - val_f1_score: 0.8093 - val_specificity: 0.9969 - val_sensitivity: 0.7753 - val_mcc: 0.8073 - val_auc: 0.9753 - lr: 5.0000e-04
# Epoch 7/25
# 358/358 [==============================] - 35s 97ms/step - loss: 0.1718 - accuracy: 0.9479 - precision: 0.9639 - recall: 0.9335 - f1_score: 0.9468 - specificity: 0.9992 - sensitivity: 0.9326 - mcc: 0.9463 - auc: 0.9994 - val_loss: 0.4938 - val_accuracy: 0.8834 - val_precision: 0.9052 - val_recall: 0.8722 - val_f1_score: 0.8875 - val_specificity: 0.9979 - val_sensitivity: 0.8722 - val_mcc: 0.8859 - val_auc: 0.9868 - lr: 5.0000e-04
# Epoch 8/25
# 358/358 [==============================] - 39s 108ms/step - loss: 0.1165 - accuracy: 0.9713 - precision: 0.9793 - recall: 0.9580 - f1_score: 0.9670 - specificity: 0.9995 - sensitivity: 0.9571 - mcc: 0.9668 - auc: 0.9995 - val_loss: 0.4829 - val_accuracy: 0.8904 - val_precision: 0.9204 - val_recall: 0.8764 - val_f1_score: 0.8954 - val_specificity: 0.9982 - val_sensitivity: 0.8764 - val_mcc: 0.8942 - val_auc: 0.9838 - lr: 5.0000e-04
# Epoch 9/25
# 358/358 [==============================] - 13s 36ms/step - loss: 0.0772 - accuracy: 0.9822 - precision: 0.9862 - recall: 0.9759 - f1_score: 0.9806 - specificity: 0.9997 - sensitivity: 0.9759 - mcc: 0.9804 - auc: 0.9998 - val_loss: 0.4473 - val_accuracy: 0.8834 - val_precision: 0.9214 - val_recall: 0.8722 - val_f1_score: 0.8945 - val_specificity: 0.9983 - val_sensitivity: 0.8722 - val_mcc: 0.8934 - val_auc: 0.9894 - lr: 5.0000e-04
# Epoch 10/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0841 - accuracy: 0.9794 - precision: 0.9847 - recall: 0.9706 - f1_score: 0.9769 - specificity: 0.9997 - sensitivity: 0.9707 - mcc: 0.9768 - auc: 0.9999 - val_loss: 1.1764 - val_accuracy: 0.7697 - val_precision: 0.7994 - val_recall: 0.7500 - val_f1_score: 0.7721 - val_specificity: 0.9956 - val_sensitivity: 0.7500 - val_mcc: 0.7684 - val_auc: 0.9487 - lr: 5.0000e-04
# Epoch 11/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.1622 - accuracy: 0.9510 - precision: 0.9613 - recall: 0.9391 - f1_score: 0.9482 - specificity: 0.9991 - sensitivity: 0.9382 - mcc: 0.9474 - auc: 0.9990 - val_loss: 0.5517 - val_accuracy: 0.8610 - val_precision: 0.8867 - val_recall: 0.8357 - val_f1_score: 0.8590 - val_specificity: 0.9975 - val_sensitivity: 0.8357 - val_mcc: 0.8571 - val_auc: 0.9833 - lr: 5.0000e-04
# Epoch 12/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.1035 - accuracy: 0.9682 - precision: 0.9760 - recall: 0.9657 - f1_score: 0.9704 - specificity: 0.9994 - sensitivity: 0.9658 - mcc: 0.9699 - auc: 0.9992 - val_loss: 0.4518 - val_accuracy: 0.8876 - val_precision: 0.9046 - val_recall: 0.8652 - val_f1_score: 0.8833 - val_specificity: 0.9979 - val_sensitivity: 0.8652 - val_mcc: 0.8817 - val_auc: 0.9871 - lr: 5.0000e-04
# Epoch 13/25
# 358/358 [==============================] - 12s 32ms/step - loss: 0.0603 - accuracy: 0.9832 - precision: 0.9863 - recall: 0.9790 - f1_score: 0.9813 - specificity: 0.9997 - sensitivity: 0.9780 - mcc: 0.9810 - auc: 0.9998 - val_loss: 0.5281 - val_accuracy: 0.8764 - val_precision: 0.9051 - val_recall: 0.8708 - val_f1_score: 0.8859 - val_specificity: 0.9979 - val_sensitivity: 0.8708 - val_mcc: 0.8841 - val_auc: 0.9846 - lr: 5.0000e-04
# Epoch 14/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0488 - accuracy: 0.9899 - precision: 0.9912 - recall: 0.9864 - f1_score: 0.9862 - specificity: 0.9998 - sensitivity: 0.9843 - mcc: 0.9860 - auc: 0.9994 - val_loss: 0.4320 - val_accuracy: 0.9003 - val_precision: 0.9192 - val_recall: 0.8947 - val_f1_score: 0.9064 - val_specificity: 0.9982 - val_sensitivity: 0.8947 - val_mcc: 0.9047 - val_auc: 0.9856 - lr: 4.5000e-04
# Epoch 15/25
# 358/358 [==============================] - 12s 32ms/step - loss: 0.0504 - accuracy: 0.9839 - precision: 0.9870 - recall: 0.9797 - f1_score: 0.9824 - specificity: 0.9997 - sensitivity: 0.9787 - mcc: 0.9822 - auc: 0.9998 - val_loss: 0.4701 - val_accuracy: 0.8820 - val_precision: 0.8974 - val_recall: 0.8722 - val_f1_score: 0.8842 - val_specificity: 0.9977 - val_sensitivity: 0.8722 - val_mcc: 0.8821 - val_auc: 0.9846 - lr: 4.0500e-04
# Epoch 16/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0402 - accuracy: 0.9899 - precision: 0.9923 - recall: 0.9860 - f1_score: 0.9889 - specificity: 0.9998 - sensitivity: 0.9860 - mcc: 0.9888 - auc: 0.9998 - val_loss: 0.4301 - val_accuracy: 0.9073 - val_precision: 0.9155 - val_recall: 0.8975 - val_f1_score: 0.9060 - val_specificity: 0.9981 - val_sensitivity: 0.8975 - val_mcc: 0.9042 - val_auc: 0.9857 - lr: 3.6450e-04
# Epoch 17/25
# 358/358 [==============================] - 12s 34ms/step - loss: 0.0245 - accuracy: 0.9941 - precision: 0.9947 - recall: 0.9923 - f1_score: 0.9910 - specificity: 0.9999 - sensitivity: 0.9902 - mcc: 0.9909 - auc: 1.0000 - val_loss: 0.4235 - val_accuracy: 0.9073 - val_precision: 0.9266 - val_recall: 0.9045 - val_f1_score: 0.9150 - val_specificity: 0.9983 - val_sensitivity: 0.9045 - val_mcc: 0.9135 - val_auc: 0.9852 - lr: 3.2805e-04
# Epoch 18/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0141 - accuracy: 0.9962 - precision: 0.9972 - recall: 0.9962 - f1_score: 0.9966 - specificity: 0.9999 - sensitivity: 0.9962 - mcc: 0.9966 - auc: 1.0000 - val_loss: 0.3816 - val_accuracy: 0.9115 - val_precision: 0.9290 - val_recall: 0.9003 - val_f1_score: 0.9130 - val_specificity: 0.9984 - val_sensitivity: 0.9003 - val_mcc: 0.9116 - val_auc: 0.9894 - lr: 2.9525e-04
# Epoch 19/25
# 358/358 [==============================] - 12s 32ms/step - loss: 0.0164 - accuracy: 0.9979 - precision: 0.9982 - recall: 0.9979 - f1_score: 0.9981 - specificity: 1.0000 - sensitivity: 0.9979 - mcc: 0.9980 - auc: 0.9998 - val_loss: 0.3721 - val_accuracy: 0.9242 - val_precision: 0.9397 - val_recall: 0.9185 - val_f1_score: 0.9283 - val_specificity: 0.9986 - val_sensitivity: 0.9185 - val_mcc: 0.9271 - val_auc: 0.9874 - lr: 2.6572e-04
# Epoch 20/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0134 - accuracy: 0.9979 - precision: 0.9986 - recall: 0.9972 - f1_score: 0.9979 - specificity: 1.0000 - sensitivity: 0.9972 - mcc: 0.9978 - auc: 0.9998 - val_loss: 0.3257 - val_accuracy: 0.9256 - val_precision: 0.9329 - val_recall: 0.9171 - val_f1_score: 0.9241 - val_specificity: 0.9985 - val_sensitivity: 0.9171 - val_mcc: 0.9227 - val_auc: 0.9896 - lr: 2.3915e-04
# Epoch 21/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0137 - accuracy: 0.9958 - precision: 0.9968 - recall: 0.9948 - f1_score: 0.9950 - specificity: 0.9999 - sensitivity: 0.9937 - mcc: 0.9950 - auc: 1.0000 - val_loss: 0.3515 - val_accuracy: 0.9185 - val_precision: 0.9249 - val_recall: 0.9171 - val_f1_score: 0.9209 - val_specificity: 0.9983 - val_sensitivity: 0.9171 - val_mcc: 0.9192 - val_auc: 0.9875 - lr: 2.1523e-04
# Epoch 22/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0094 - accuracy: 0.9983 - precision: 0.9982 - recall: 0.9976 - f1_score: 0.9979 - specificity: 1.0000 - sensitivity: 0.9976 - mcc: 0.9978 - auc: 1.0000 - val_loss: 0.3518 - val_accuracy: 0.9228 - val_precision: 0.9289 - val_recall: 0.9171 - val_f1_score: 0.9224 - val_specificity: 0.9984 - val_sensitivity: 0.9171 - val_mcc: 0.9208 - val_auc: 0.9875 - lr: 1.9371e-04
# Epoch 23/25
# 358/358 [==============================] - 12s 32ms/step - loss: 0.0097 - accuracy: 0.9990 - precision: 0.9990 - recall: 0.9990 - f1_score: 0.9990 - specificity: 1.0000 - sensitivity: 0.9990 - mcc: 0.9989 - auc: 0.9996 - val_loss: 0.3196 - val_accuracy: 0.9368 - val_precision: 0.9404 - val_recall: 0.9312 - val_f1_score: 0.9354 - val_specificity: 0.9986 - val_sensitivity: 0.9312 - val_mcc: 0.9341 - val_auc: 0.9876 - lr: 1.7434e-04
# Epoch 24/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0058 - accuracy: 0.9993 - precision: 0.9993 - recall: 0.9990 - f1_score: 0.9984 - specificity: 1.0000 - sensitivity: 0.9979 - mcc: 0.9985 - auc: 0.9998 - val_loss: 0.3224 - val_accuracy: 0.9354 - val_precision: 0.9472 - val_recall: 0.9326 - val_f1_score: 0.9393 - val_specificity: 0.9988 - val_sensitivity: 0.9326 - val_mcc: 0.9382 - val_auc: 0.9897 - lr: 1.5691e-04
# Epoch 25/25
# 358/358 [==============================] - 12s 33ms/step - loss: 0.0071 - accuracy: 0.9990 - precision: 0.9989 - recall: 0.9983 - f1_score: 0.9986 - specificity: 1.0000 - sensitivity: 0.9983 - mcc: 0.9986 - auc: 0.9998 - val_loss: 0.2813 - val_accuracy: 0.9298 - val_precision: 0.9469 - val_recall: 0.9270 - val_f1_score: 0.9362 - val_specificity: 0.9988 - val_sensitivity: 0.9270 - val_mcc: 0.9352 - val_auc: 0.9918 - lr: 1.4121e-04

# %%
execution_time_parts = []
avg_time_parts = []

for unit in [(3600, 'hours'), (60, 'minutes'), (1, 'seconds'), (0.001, 'milliseconds')]:
    total_value = int(time_callback.total_train_time // unit[0])
    avg_value = int(np.mean(time_callback.epoch_times) // unit[0])

    if total_value > 0 or unit[0] == 0.001:
        execution_time_parts.append((total_value, unit[1]))
    if avg_value > 0 or unit[0] == 0.001:
        avg_time_parts.append((avg_value, unit[1]))

    time_callback.total_train_time -= total_value * unit[0]
    time_callback.epoch_times = [time - avg_value * unit[0] for time in time_callback.epoch_times]

execution_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in execution_time_parts if value > 0
])

avg_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in avg_time_parts if value > 0
])

print(f"Model training took {execution_time_string}")
print(f"Average time per epoch: {avg_time_string}")
# Out:
# Model training took 07 minutes, 47 seconds, 535 milliseconds
# Average time per epoch: 18 seconds, 683 milliseconds

# %%
_ = model.evaluate(test_gen, steps = test_steps)
# Out:
# 112/112 [==============================] - 13s 115ms/step - loss: 0.2454 - accuracy: 0.9587 - precision: 0.9650 - recall: 0.9542 - f1_score: 0.9591 - specificity: 0.9992 - sensitivity: 0.9542 - mcc: 0.9583 - auc: 0.9913

# %%
def plot_metrics(hist, metric_name_list):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        hist: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot

    Returns:
        None
    """
    num_metrics = len(metric_name_list)

    figure, axes = plt.subplots(num_metrics, figsize=(10, 6 * num_metrics))

    rng = range(1, len(hist.history[metric_name_list[0]]) + 1)

    for ax, metric_n in zip(axes, metric_name_list):
        metric = hist.history[metric_n]
        v_metric = hist.history[f"val_{metric_n}"]

        ax.plot(rng, metric, label=metric_n)
        ax.plot(rng, v_metric, label=f"val_{metric_n}")
        ax.legend()
        ax.set_xlabel("Epochs")

        if metric_n in ("auc", "mcc"):
            ax.set_ylabel(metric_n.upper())
            ax.set_title(metric_n.upper() + " vs Epochs")
        else:
            ax.set_ylabel(metric_n.capitalize())
            ax.set_title(metric_n.capitalize() + " vs Epochs")

        max_loss = max(max(metric), max(v_metric))
        min_loss = min(min(metric), min(v_metric))
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()

    plt.show()

# %%
metric_names = ["loss", "accuracy","f1_score",
                "specificity", "sensitivity", "mcc"]
plot_metrics(history, metric_names)

# %%
def generate_classification_report(model, test_generator, test_steps, batch_size, target_names):
    """
    Generate a classification report, accuracy, and number of errors for a given model and test generator.

    Args:
        model (object): The trained model.
        test_generator (object): The test data generator.
        test_steps (int): The number of steps to iterate over the test generator.
        batch_size (int): The batch size for generating predictions.
        target_names (list): List of target class names for the classification report.

    Returns:
        tuple: A tuple containing true labels, predicted labels, and the classification report.
    """
    predicted_labels = []
    true_labels = []

    for i in range(test_steps):
        batch_data, batch_true_labels = next(test_generator)

        batch_predicted_labels = model.predict_on_batch(batch_data)
        batch_predicted_labels = np.argmax(batch_predicted_labels, axis=1)

        predicted_labels.extend(batch_predicted_labels)
        true_labels.extend(batch_true_labels)

    true_labels = np.array(true_labels)

    if len(true_labels[0]) > 1:
        true_labels = np.argmax(true_labels, axis=1)

    report = classification_report(
        true_labels,
        predicted_labels,
        target_names=target_names,
        digits=4,
        zero_division=1
    )

    accuracy = accuracy_score(true_labels, predicted_labels)
    num_errors = np.sum(true_labels != predicted_labels)

    print(report)
    print(f'There were {num_errors} errors in {len(predicted_labels)} tests for an accuracy of {accuracy*100:6.2f}')

    return true_labels, predicted_labels

# %%
true_labels, predicted_labels = generate_classification_report(
    model, test_gen, test_steps, BATCH_SIZE, df["label"].unique()
)
# Out:
#                         precision    recall  f1-score   support
#
#         Astrocitoma T1     1.0000    0.9429    0.9706        35
#       Astrocitoma T1C+     0.9375    0.9783    0.9574        46
#         Astrocitoma T2     0.9714    1.0000    0.9855        34
#           Carcinoma T1     1.0000    1.0000    1.0000        13
#         Carcinoma T1C+     0.9565    1.0000    0.9778        22
#           Carcinoma T2     1.0000    1.0000    1.0000        15
#          Ependimoma T1     1.0000    0.6667    0.8000         9
#        Ependimoma T1C+     0.7500    0.9000    0.8182        10
#          Ependimoma T2     1.0000    1.0000    1.0000        11
#       Ganglioglioma T1     0.8000    1.0000    0.8889         4
#     Ganglioglioma T1C+     1.0000    1.0000    1.0000         3
#       Ganglioglioma T2     1.0000    0.4000    0.5714         5
#           Germinoma T1     1.0000    1.0000    1.0000         5
#         Germinoma T1C+     1.0000    1.0000    1.0000         8
#           Germinoma T2     1.0000    0.7143    0.8333         7
#        Glioblastoma T1     1.0000    0.9091    0.9524        11
#      Glioblastoma T1C+     0.9500    1.0000    0.9744        19
#        Glioblastoma T2     1.0000    0.9091    0.9524        11
#           Granuloma T1     0.8000    0.6667    0.7273         6
#         Granuloma T1C+     1.0000    0.8333    0.9091         6
#           Granuloma T2     0.5000    0.3333    0.4000         3
#      Meduloblastoma T1     1.0000    1.0000    1.0000         4
#    Meduloblastoma T1C+     1.0000    1.0000    1.0000        13
#      Meduloblastoma T2     1.0000    1.0000    1.0000         8
#          Meningioma T1     0.9630    0.9630    0.9630        54
#        Meningioma T1C+     0.9481    0.9865    0.9669        74
#          Meningioma T2     0.9778    0.9362    0.9565        47
#         Neurocitoma T1     0.9630    1.0000    0.9811        26
#       Neurocitoma T1C+     1.0000    1.0000    1.0000        45
#         Neurocitoma T2     0.8696    0.9524    0.9091        21
#   Oligodendroglioma T1     1.0000    1.0000    1.0000        17
# Oligodendroglioma T1C+     1.0000    1.0000    1.0000        14
#   Oligodendroglioma T2     0.9286    1.0000    0.9630        13
#            Papiloma T1     0.9286    1.0000    0.9630        13
#          Papiloma T1C+     1.0000    0.9545    0.9767        22
#            Papiloma T2     0.9286    1.0000    0.9630        13
#          Schwannoma T1     1.0000    0.9667    0.9831        30
#        Schwannoma T1C+     0.9250    0.9487    0.9367        39
#          Schwannoma T2     1.0000    0.9600    0.9796        25
#         Tuberculoma T1     1.0000    1.0000    1.0000         6
#       Tuberculoma T1C+     0.9375    0.8824    0.9091        17
#         Tuberculoma T2     0.8000    0.5714    0.6667         7
#             _NORMAL T1     0.9615    1.0000    0.9804        50
#             _NORMAL T2     0.9298    0.9815    0.9550        54
#
#               accuracy                         0.9587       895
#              macro avg     0.9483    0.9172    0.9266       895
#           weighted avg     0.9595    0.9587    0.9570       895
#
# There were 37 errors in 895 tests for an accuracy of  95.87

# %%
def confusion_matrix(true_labels, predicted_labels, num_classes):
    """
    Compute the confusion matrix.

    Args:
        true_labels (list or numpy.ndarray): Array-like object of true labels.
        predicted_labels (list or numpy.ndarray): Array-like object of predicted labels.
        num_classes (int): Number of classes.

    Returns:
        numpy.ndarray: Confusion matrix.
    """
    cm = np.zeros((num_classes, num_classes), dtype=int)
    np.add.at(cm, (true_labels, predicted_labels), 1)
    return cm

# %%
cm = confusion_matrix(true_labels, predicted_labels, num_classes)

plt.figure(figsize=(15, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels= df["label"].unique(), yticklabels= df["label"].unique())

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
