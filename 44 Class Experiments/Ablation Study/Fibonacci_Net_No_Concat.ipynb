# %%
import os
import itertools

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout,BatchNormalization

import warnings
warnings.filterwarnings('ignore')

print("Modules Loaded")
# Out:
# Modules Loaded

# %%
import os
import cv2
import glob
import math
import time
import random
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import multiprocessing
import tensorflow as tf
from pathlib import Path
import concurrent.futures
import keras.backend as K
from time import perf_counter
from functools import lru_cache
import matplotlib.pyplot as plt
from keras import layers, models
from keras.optimizers import Adam
from PIL import Image, ImageEnhance
from joblib import Parallel, delayed
from collections import defaultdict, Counter
from sklearn.preprocessing import LabelEncoder
from keras.metrics import Precision, Recall, AUC
from keras.callbacks import LearningRateScheduler
from keras.utils import plot_model, to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from concurrent.futures import ThreadPoolExecutor, as_completed
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Read data and store in df

# %%
def main(train_data_path):
    
    """
    return training and testing dataframes including 2 columns image path and its label
    
    Args:
      train_data_path (string): string includes your train data path
      test_data_path (string): string includes your test data path
      note: data_path argument must contains your classes dirs
      
    Returns:
      train_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the training images and the label of each image
      test_df (dataframe):  It consists of two columns (the path of the image and its label) and contains records of the path of the testing images and the label of each image

    """
    
    for dirs in [train_data_path]:

        filepaths = []
        labels = []
        classes_list = sorted(os.listdir(dirs))

        filepaths,labels = get_fileList(classes_list, dirs, filepaths, labels)
        
        train_df = obtain_train_df(filepaths, labels)
        
            
    return train_df



def get_fileList(classes_list, dirs, filepaths, labels):
    
    
    """
    return file paths list including all full image paths and label for each one
    
    Args:
      classes_list (list): list includes name of classes dirs
      dirs (string): the data path
      filepaths (list): empty list to fill with images paths later
      labels (list): empty list to fill with each image label later
      
    Returns:
      count (scalar):  number of images in your dataset
    """
    
    
    for s_class in classes_list:
        
        label = s_class
        classpath = os.path.join(dirs, s_class)
        flist = sorted(os.listdir(classpath))
        
        store_image_names_and_its_labels(flist, classpath, filepaths, labels, label)
        
    return filepaths, labels


def store_image_names_and_its_labels(flist, classpath, filepaths, labels, label):
    
    """
    return nothing, it fills the filepaths list with all the images paths and its labels
    
    Args:
      flist (list) : contains all the image names in certain class
      classes_list (list): list includes name of classes dirs
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset
      label (string): label for a specific image
      
    Returns:
      nothing
    """
    
    
    for file in flist:
        file_path = os.path.join(classpath, file)
        filepaths.append(file_path)
        labels.append(label)



def obtain_train_df(filepaths, labels):
    
    """
    Return Dataframe with 2 columns contains each image path with its label
    
    Args:
      filepaths (list): stores all the images paths
      labels (list): stores the label of each image in the dataset
      
    Returns:
      train_df (DataFrame):  Dataframe with 2 columns contains each image path with its label
    """
    
    train_df =pd.DataFrame({
        'image_path' : filepaths,
        'label' : labels
    })
    return train_df

# %%
data_dir = "/kaggle/input/brain-tumor-mri-images-44c"

data_df = main(data_dir)

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
data_df.head()
# Out:
#                                           image_path           label
# 0  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 1  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 2  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 3  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1
# 4  /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1

# %%
num_classes = len(data_df['label'].unique())
print(f"We have {num_classes} classes")
print(f"We have {data_df.shape[0]} images")
# Out:
# We have 44 classes
# We have 4479 images

# %%
num_classes = len(data_df['label'].value_counts())
data_df['label'].value_counts()
df = data_df

# %% [markdown]
# #### Split data into train, valid, test

# %%
train_df, test_df = train_test_split(df, train_size=0.8, random_state=42, stratify=df['label'])

train_df, valid_df = train_test_split(train_df, train_size=0.8, random_state=42, stratify=train_df['label'])

# %%
print(f"Train shape: {train_df.shape}")
print(f"Validation shape: {valid_df.shape}")
print(f"Test shape: {test_df.shape}")
# Out:
# Train shape: (2866, 2)
# Validation shape: (717, 2)
# Test shape: (896, 2)

# %%
train_df
# Out:
#                                              image_path             label
# 2760  /kaggle/input/brain-tumor-mri-images-44c/Neuro...  Neurocitoma T1C+
# 4306  /kaggle/input/brain-tumor-mri-images-44c/_NORM...        _NORMAL T2
# 4124  /kaggle/input/brain-tumor-mri-images-44c/_NORM...        _NORMAL T1
# 211   /kaggle/input/brain-tumor-mri-images-44c/Astro...  Astrocitoma T1C+
# 2870  /kaggle/input/brain-tumor-mri-images-44c/Neuro...    Neurocitoma T2
# ...                                                 ...               ...
# 1857  /kaggle/input/brain-tumor-mri-images-44c/Menin...   Meningioma T1C+
# 3381  /kaggle/input/brain-tumor-mri-images-44c/Schwa...     Schwannoma T1
# 1296  /kaggle/input/brain-tumor-mri-images-44c/Gliob...   Glioblastoma T2
# 4447  /kaggle/input/brain-tumor-mri-images-44c/_NORM...        _NORMAL T2
# 1358  /kaggle/input/brain-tumor-mri-images-44c/Granu...      Granuloma T1
#
# [2866 rows x 2 columns]

# %% [markdown]
# #### ImageDataGenerator

# %%
BATCH_SIZE = 8
image_size = (224, 224)

gen = ImageDataGenerator()

train_gen = gen.flow_from_dataframe(train_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
train_steps = len(train_df) // BATCH_SIZE

valid_gen = gen.flow_from_dataframe(valid_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
val_steps = len(valid_df) // BATCH_SIZE

test_gen = gen.flow_from_dataframe(test_df, x_col='image_path', y_col='label', class_mode='categorical',
                                   color_mode = 'rgb', target_size=image_size, batch_size=BATCH_SIZE)
test_steps = len(test_df) // BATCH_SIZE
# Out:
# Found 2866 validated image filenames belonging to 44 classes.
# Found 717 validated image filenames belonging to 44 classes.
# Found 895 validated image filenames belonging to 44 classes.

# %% [markdown]
# ### Model Structure

# %%
class AvgTwiceMaxPooling2D(layers.Layer):
    """
    Custom Keras layer that performs average - twice-maximum pooling on the input.

    Args:
        pool_size (int, optional): Pooling window size. Defaults to 2.
        strides (int, optional): Stride size for pooling. Defaults to 2.
        padding (str, optional): Padding mode ('same' or 'valid'). Defaults to 'same'.

    Returns:
        tf.Tensor: Output tensor after applying twice-maximum average pooling.
    """
    def __init__(self, pool_size=2, strides=2, padding='same', **kwargs):
        super(AvgTwiceMaxPooling2D, self).__init__(**kwargs)
        self.pool_size = pool_size
        self.strides = strides
        self.padding = padding

    @tf.function
    def call(self, inputs, **kwargs):
        """
        Apply the average - twice-maximum pooling operation to the input tensor.

        Args:
            inputs (tf.Tensor): Input tensor.

        Returns:
            tf.Tensor: Output tensor after applying twice-maximum average pooling.
            :param **kwargs:
        """
        # Apply max pooling and average pooling
        max_pooled = layers.MaxPooling2D(pool_size=self.pool_size, strides=self.strides, padding=self.padding)(inputs)
        avg_pooled = layers.AveragePooling2D(pool_size=self.pool_size, strides=self.strides, padding=self.padding)(inputs)

        # Apply the average - twice-maximum pooling operation
        output = tf.subtract(avg_pooled, tf.add(max_pooled, max_pooled))
        return output

# %%
from tensorflow.keras.layers import LeakyReLU
def create_brian_tumor_model(input_shape, n_classes):
    """
    Create a convolutional neural network model optimized for image classification.

    Args:
        input_shape (tuple): Shape of input images (height, width, channels).
        n_classes (int): Number of classes for classification.

    Returns:
        tf.keras.Model: Created CNN model.
    """
    model_name = 'MRINet'

    input_layer = layers.Input(shape=input_shape, name='Input')

    blk1 = layers.Conv2D(21, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv1')(input_layer)
    blk1 = layers.BatchNormalization()(blk1)
    blk1 = layers.MaxPooling2D(strides=2, name='MaxPool1')(blk1)

    blk2 = layers.Conv2D(34, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv2')(blk1)
    blk2 = layers.BatchNormalization()(blk2)
    blk2 = layers.MaxPooling2D(strides=2, name='MaxPool2')(blk2)

    avgtwicemax = AvgTwiceMaxPooling2D(pool_size=(3, 3))(blk2)

    blk3 = layers.Conv2D(55, kernel_size=3, strides=1, padding='same', activation='relu', name='Conv3')(blk2)
    blk3 = layers.MaxPooling2D(strides=2, name='MaxPool3')(blk3) 
    norm = layers.BatchNormalization()(blk3) 

#     concat = layers.Concatenate(name="VerticalConcat2")([norm, avgtwicemax])

#     # concat from 3 to 5
#     blk = layers.Conv2D(24, kernel_size=3, strides=1, padding='same', activation='relu', name='ConvC')(norm)
#     blk = layers.BatchNormalization()(blk)
#     blk = AvgTwiceMaxPooling2D(pool_size=(3, 3))(blk)


    blk4 = layers.Conv2D(89, kernel_size=3, padding='same', activation='relu', name='Conv4')(norm)
    blk4 = layers.BatchNormalization()(blk4) 
    blk4 = layers.MaxPooling2D(strides=2, name='MaxPool4')(blk4)

#     concat2 = layers.Concatenate(name="VerticalConcat3")([blk4, blk])
    # added block 5
    blk5 = layers.Conv2D(144, kernel_size=3, padding='same', activation='relu', name='Conv5')(blk4)
    blk5 = layers.BatchNormalization()(blk5) 
    blk5 = layers.MaxPooling2D(strides=2, name='MaxPool5')(blk5)

    # added block 6
    blk6 = layers.Conv2D(233, kernel_size=3, padding='same',  activation="relu", name='Conv7')(blk5)
    blk6 = layers.DepthwiseConv2D(depth_multiplier=1, kernel_size=(3, 3), padding='same', activation="relu", name='DConv4')(blk6)
    blk6 = layers.BatchNormalization()(blk6) 

    # added block 7
    blk7 = layers.Conv2D(377, kernel_size=3, padding='same',  activation=LeakyReLU(alpha=0.01), name='Conv8')(blk6)
    blk7 = layers.DepthwiseConv2D(depth_multiplier=2, kernel_size=(3, 3), padding='same', activation="relu", name='DConv5')(blk7)
    blk7 = layers.BatchNormalization()(blk7) 

    gap = layers.GlobalAveragePooling2D(name='GAP')(blk7)

    output = layers.Dense(n_classes, activation='softmax', name='Output')(gap)

    model = tf.keras.Model(inputs=input_layer, outputs=output, name=model_name)
    return model

# %%
num_classes
# Out:
# 44

# %%
input_shape = (224, 224, 3)
model = create_brian_tumor_model(input_shape, num_classes)
model.summary()
# Out:
# Model: "MRINet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1 (Conv2D)                  │ (None, 224, 224, 21)   │           588 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_59          │ (None, 224, 224, 21)   │            84 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool1 (MaxPooling2D)         │ (None, 112, 112, 21)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2 (Conv2D)                  │ (None, 112, 112, 34)   │         6,460 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_60          │ (None, 112, 112, 34)   │           136 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool2 (MaxPooling2D)         │ (None, 56, 56, 34)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3 (Conv2D)                  │ (None, 56, 56, 55)     │        16,885 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool3 (MaxPooling2D)         │ (None, 28, 28, 55)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_61          │ (None, 28, 28, 55)     │           220 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv4 (Conv2D)                  │ (None, 28, 28, 89)     │        44,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_62          │ (None, 28, 28, 89)     │           356 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool4 (MaxPooling2D)         │ (None, 14, 14, 89)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv5 (Conv2D)                  │ (None, 14, 14, 144)    │       115,488 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_63          │ (None, 14, 14, 144)    │           576 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ MaxPool5 (MaxPooling2D)         │ (None, 7, 7, 144)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv7 (Conv2D)                  │ (None, 7, 7, 233)      │       302,201 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DConv4 (DepthwiseConv2D)        │ (None, 7, 7, 233)      │         2,330 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_64          │ (None, 7, 7, 233)      │           932 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv8 (Conv2D)                  │ (None, 7, 7, 377)      │       790,946 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DConv5 (DepthwiseConv2D)        │ (None, 7, 7, 754)      │         7,540 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_65          │ (None, 7, 7, 754)      │         3,016 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ GAP (GlobalAveragePooling2D)    │ (None, 754)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 44)             │        33,220 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,325,122 (5.05 MB)
#  Trainable params: 1,322,462 (5.04 MB)
#  Non-trainable params: 2,660 (10.39 KB)

# %%
plot_model(model, show_shapes=True)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.metrics import Precision, Recall, AUC

def create_metrics():
    """
    Creates instances of various metrics for evaluating model performance.

    Returns:
        tuple: A tuple of the metrics: (recall, precision, f1_score, auc, sensitivity, specificity, mcc).
    """
    @tf.function
    def f1_score(y_true, y_pred):
        """
        Calculates the F1 score.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: F1 score.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        tp = true_positive(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        precision = tp / (tp + fp + K.epsilon())
        recall = tp / (tp + fn + K.epsilon())

        return 2 * (precision * recall) / (precision + recall + K.epsilon())

    @tf.function
    def specificity(y_true, y_pred):
        """
        Calculates the specificity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Specificity.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)

        return tn / (tn + fp + K.epsilon())

    @tf.function
    def sensitivity(y_true, y_pred):
        """
        Calculates the sensitivity.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Sensitivity.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        tp = true_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        return tp / (tp + fn + K.epsilon())

    @tf.function
    def mcc(y_true, y_pred):
        """
        Calculates the Matthews correlation coefficient (MCC).

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Matthews correlation coefficient.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        tp = true_positive(y_true, y_pred)
        tn = true_negative(y_true, y_pred)
        fp = false_positive(y_true, y_pred)
        fn = false_negative(y_true, y_pred)

        numerator = (tp * tn - fp * fn)
        denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

        return numerator / (denominator + K.epsilon())

    @tf.function
    def true_positive(y_true, y_pred):
        """
        Calculates the number of true positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true positives.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        y_pred_pos, _, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_pos)

    @tf.function
    def false_positive(y_true, y_pred):
        """
        Calculates the number of false positives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false positives.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        y_pred_pos, _, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_pos)

    @tf.function
    def false_negative(y_true, y_pred):
        """
        Calculates the number of false negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of false negatives.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        _, y_pred_neg, y_pos, _ = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_pos * y_pred_neg)

    @tf.function
    def true_negative(y_true, y_pred):
        """
        Calculates the number of true negatives.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            Tensor: Number of true negatives.
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        _, y_pred_neg, _, y_neg = calculate_confusion_matrix(y_true, y_pred)
        return K.sum(y_neg * y_pred_neg)

    @tf.function
    def calculate_confusion_matrix(y_true, y_pred):
        """
        Calculates the components of the confusion matrix.

        Args:
            y_true: True labels.
            y_pred: Predicted labels.

        Returns:
            tuple: A tuple containing the components of the confusion matrix: (y_pred_pos, y_pred_neg, y_pos, y_neg).
        """
        y_pred_pos = K.round(K.clip(y_pred, 0, 1))
        y_pred_neg = 1 - y_pred_pos
        y_pos = K.round(K.clip(y_true, 0, 1))
        y_neg = 1 - y_pos
        return y_pred_pos, y_pred_neg, y_pos, y_neg

    precision_metric = Precision()
    recall_metric = Recall()
    f1_score_metric = f1_score
    specificity_metric = specificity
    sensitivity_metric = sensitivity
    mcc_metric = mcc
    auc_metric = AUC()

    return (
        precision_metric,
        recall_metric,
        f1_score_metric,
        specificity_metric,
        sensitivity_metric,
        mcc_metric,
        auc_metric,
    )

# %%
metrics = ['accuracy']
metrics.extend(list(create_metrics()))
model.compile(
    optimizer = Adam(learning_rate = 5e-4),
    loss = 'categorical_crossentropy',
    metrics=metrics,

)

# %%
class TimeCallback(tf.keras.callbacks.Callback):
    """Custom callback to record epoch times and total training time."""

    def on_train_begin(self, logs=None):
        """Initialize training start time and epoch times."""
        self.train_start_time = time.perf_counter()
        self.epoch_times = []

    def on_epoch_begin(self, epoch, logs=None):
        """Record start time of each epoch."""
        self.epoch_start_time = time.perf_counter()

    def on_epoch_end(self, epoch, logs=None):
        """Calculate and store epoch time."""
        epoch_time = time.perf_counter() - self.epoch_start_time
        self.epoch_times.append(epoch_time)

    def on_train_end(self, logs=None):
        """Calculate total training time."""
        self.total_train_time = time.perf_counter() - self.train_start_time

# Create an instance of the TimeCallback
time_callback = TimeCallback()

# %%
#@title Learning rate scheduler

from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler

def lr_schedule(epoch,lr):
    if epoch < 13:
        return lr
    else:
        return 0.9*lr


lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
TOTAL_EPOCHS = 25

start_time = perf_counter()
history = model.fit(
    train_gen,
    epochs=TOTAL_EPOCHS,
    validation_data=valid_gen,
    steps_per_epoch=train_steps,
    validation_steps=val_steps,
    callbacks=[time_callback,lr_scheduler]
)
end_time = perf_counter()
# Out:
# Epoch 1/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 25s 45ms/step - accuracy: 0.2405 - auc_7: 0.7936 - f1_score: 0.0741 - loss: 3.0140 - mcc: 0.0952 - precision_7: 0.5300 - recall_7: 0.0472 - sensitivity: 0.0471 - specificity: 0.9995 - val_accuracy: 0.3876 - val_auc_7: 0.9148 - val_f1_score: 0.0000e+00 - val_loss: 2.8340 - val_mcc: 0.0000e+00 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - learning_rate: 5.0000e-04
# Epoch 2/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7500 - auc_7: 0.9662 - f1_score: 0.6154 - loss: 1.4561 - mcc: 0.6261 - precision_7: 0.8000 - recall_7: 0.5000 - sensitivity: 0.5000 - specificity: 0.9971 - val_accuracy: 0.4000 - val_auc_7: 0.9716 - val_f1_score: 0.0000e+00 - val_loss: 2.6224 - val_mcc: 0.0000e+00 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00 - val_sensitivity: 0.0000e+00 - val_specificity: 1.0000 - learning_rate: 5.0000e-04
# Epoch 3/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.5711 - auc_7: 0.9644 - f1_score: 0.4943 - loss: 1.5049 - mcc: 0.5329 - precision_7: 0.8328 - recall_7: 0.3737 - sensitivity: 0.3711 - specificity: 0.9983 - val_accuracy: 0.6601 - val_auc_7: 0.9673 - val_f1_score: 0.6414 - val_loss: 1.2500 - val_mcc: 0.6581 - val_precision_7: 0.8352 - val_recall_7: 0.5337 - val_sensitivity: 0.5337 - val_specificity: 0.9976 - learning_rate: 5.0000e-04
# Epoch 4/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 140us/step - accuracy: 0.6250 - auc_7: 0.9824 - f1_score: 0.5455 - loss: 1.3404 - mcc: 0.6080 - precision_7: 1.0000 - recall_7: 0.3750 - sensitivity: 0.3750 - specificity: 1.0000 - val_accuracy: 0.6000 - val_auc_7: 0.9870 - val_f1_score: 0.6667 - val_loss: 1.1549 - val_mcc: 0.6641 - val_precision_7: 0.7500 - val_recall_7: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.9953 - learning_rate: 5.0000e-04
# Epoch 5/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.7560 - auc_7: 0.9883 - f1_score: 0.7191 - loss: 0.8702 - mcc: 0.7316 - precision_7: 0.8914 - recall_7: 0.6171 - sensitivity: 0.6162 - specificity: 0.9983 - val_accuracy: 0.7683 - val_auc_7: 0.9794 - val_f1_score: 0.7542 - val_loss: 0.8667 - val_mcc: 0.7551 - val_precision_7: 0.8319 - val_recall_7: 0.7022 - val_sensitivity: 0.7022 - val_specificity: 0.9967 - learning_rate: 5.0000e-04
# Epoch 6/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 111us/step - accuracy: 0.8750 - auc_7: 0.9262 - f1_score: 0.7143 - loss: 0.9900 - mcc: 0.7163 - precision_7: 0.8333 - recall_7: 0.6250 - sensitivity: 0.6250 - specificity: 0.9971 - val_accuracy: 0.4000 - val_auc_7: 0.9688 - val_f1_score: 0.3333 - val_loss: 1.5685 - val_mcc: 0.4431 - val_precision_7: 1.0000 - val_recall_7: 0.2000 - val_sensitivity: 0.2000 - val_specificity: 1.0000 - learning_rate: 5.0000e-04
# Epoch 7/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.8643 - auc_7: 0.9970 - f1_score: 0.8349 - loss: 0.4828 - mcc: 0.8388 - precision_7: 0.9310 - recall_7: 0.7687 - sensitivity: 0.7683 - specificity: 0.9987 - val_accuracy: 0.8272 - val_auc_7: 0.9849 - val_f1_score: 0.8221 - val_loss: 0.6266 - val_mcc: 0.8212 - val_precision_7: 0.8694 - val_recall_7: 0.7851 - val_sensitivity: 0.7851 - val_specificity: 0.9973 - learning_rate: 5.0000e-04
# Epoch 8/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 108us/step - accuracy: 0.8750 - auc_7: 0.9996 - f1_score: 0.8750 - loss: 0.2187 - mcc: 0.8721 - precision_7: 0.8750 - recall_7: 0.8750 - sensitivity: 0.8750 - specificity: 0.9971 - val_accuracy: 1.0000 - val_auc_7: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.2112 - val_mcc: 1.0000 - val_precision_7: 1.0000 - val_recall_7: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 5.0000e-04
# Epoch 9/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9338 - auc_7: 0.9986 - f1_score: 0.9252 - loss: 0.2736 - mcc: 0.9259 - precision_7: 0.9711 - recall_7: 0.8880 - sensitivity: 0.8879 - specificity: 0.9994 - val_accuracy: 0.8750 - val_auc_7: 0.9845 - val_f1_score: 0.8751 - val_loss: 0.5211 - val_mcc: 0.8742 - val_precision_7: 0.9160 - val_recall_7: 0.8427 - val_sensitivity: 0.8427 - val_specificity: 0.9982 - learning_rate: 5.0000e-04
# Epoch 10/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 109us/step - accuracy: 1.0000 - auc_7: 1.0000 - f1_score: 1.0000 - loss: 0.1643 - mcc: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.8000 - val_auc_7: 0.9944 - val_f1_score: 0.8000 - val_loss: 0.5735 - val_mcc: 0.7953 - val_precision_7: 0.8000 - val_recall_7: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9953 - learning_rate: 5.0000e-04
# Epoch 11/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9560 - auc_7: 0.9991 - f1_score: 0.9526 - loss: 0.1793 - mcc: 0.9523 - precision_7: 0.9736 - recall_7: 0.9384 - sensitivity: 0.9367 - specificity: 0.9994 - val_accuracy: 0.8652 - val_auc_7: 0.9835 - val_f1_score: 0.8684 - val_loss: 0.5636 - val_mcc: 0.8668 - val_precision_7: 0.8970 - val_recall_7: 0.8441 - val_sensitivity: 0.8441 - val_specificity: 0.9977 - learning_rate: 5.0000e-04
# Epoch 12/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 103us/step - accuracy: 1.0000 - auc_7: 1.0000 - f1_score: 1.0000 - loss: 0.0898 - mcc: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 1.0000 - val_auc_7: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0116 - val_mcc: 1.0000 - val_precision_7: 1.0000 - val_recall_7: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 5.0000e-04
# Epoch 13/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 17s 47ms/step - accuracy: 0.9654 - auc_7: 0.9994 - f1_score: 0.9618 - loss: 0.1382 - mcc: 0.9616 - precision_7: 0.9788 - recall_7: 0.9489 - sensitivity: 0.9482 - specificity: 0.9995 - val_accuracy: 0.8652 - val_auc_7: 0.9887 - val_f1_score: 0.8632 - val_loss: 0.5531 - val_mcc: 0.8612 - val_precision_7: 0.8851 - val_recall_7: 0.8441 - val_sensitivity: 0.8441 - val_specificity: 0.9975 - learning_rate: 5.0000e-04
# Epoch 14/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 112us/step - accuracy: 1.0000 - auc_7: 1.0000 - f1_score: 1.0000 - loss: 0.0502 - mcc: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.8000 - val_auc_7: 0.9991 - val_f1_score: 0.8000 - val_loss: 0.2921 - val_mcc: 0.7953 - val_precision_7: 0.8000 - val_recall_7: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9953 - learning_rate: 4.5000e-04
# Epoch 15/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9715 - auc_7: 0.9999 - f1_score: 0.9672 - loss: 0.1159 - mcc: 0.9673 - precision_7: 0.9813 - recall_7: 0.9585 - sensitivity: 0.9561 - specificity: 0.9996 - val_accuracy: 0.8638 - val_auc_7: 0.9845 - val_f1_score: 0.8674 - val_loss: 0.5137 - val_mcc: 0.8647 - val_precision_7: 0.8768 - val_recall_7: 0.8596 - val_sensitivity: 0.8596 - val_specificity: 0.9972 - learning_rate: 4.0500e-04
# Epoch 16/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - accuracy: 0.8750 - auc_7: 0.9996 - f1_score: 0.9333 - loss: 0.1573 - mcc: 0.9341 - precision_7: 1.0000 - recall_7: 0.8750 - sensitivity: 0.8750 - specificity: 1.0000 - val_accuracy: 0.6000 - val_auc_7: 0.9944 - val_f1_score: 0.6000 - val_loss: 0.9946 - val_mcc: 0.5907 - val_precision_7: 0.6000 - val_recall_7: 0.6000 - val_sensitivity: 0.6000 - val_specificity: 0.9907 - learning_rate: 3.6450e-04
# Epoch 17/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9866 - auc_7: 0.9992 - f1_score: 0.9845 - loss: 0.0694 - mcc: 0.9843 - precision_7: 0.9886 - recall_7: 0.9809 - sensitivity: 0.9811 - specificity: 0.9997 - val_accuracy: 0.9087 - val_auc_7: 0.9893 - val_f1_score: 0.9105 - val_loss: 0.3726 - val_mcc: 0.9093 - val_precision_7: 0.9287 - val_recall_7: 0.8961 - val_sensitivity: 0.8961 - val_specificity: 0.9984 - learning_rate: 3.2805e-04
# Epoch 18/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 106us/step - accuracy: 1.0000 - auc_7: 1.0000 - f1_score: 1.0000 - loss: 0.1397 - mcc: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 1.0000 - val_auc_7: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0071 - val_mcc: 1.0000 - val_precision_7: 1.0000 - val_recall_7: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 2.9525e-04
# Epoch 19/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9967 - auc_7: 1.0000 - f1_score: 0.9957 - loss: 0.0198 - mcc: 0.9958 - precision_7: 0.9984 - recall_7: 0.9954 - sensitivity: 0.9938 - specificity: 1.0000 - val_accuracy: 0.9242 - val_auc_7: 0.9896 - val_f1_score: 0.9260 - val_loss: 0.3096 - val_mcc: 0.9248 - val_precision_7: 0.9369 - val_recall_7: 0.9171 - val_sensitivity: 0.9171 - val_specificity: 0.9986 - learning_rate: 2.6572e-04
# Epoch 20/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 108us/step - accuracy: 1.0000 - auc_7: 1.0000 - f1_score: 1.0000 - loss: 0.0286 - mcc: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 1.0000 - val_auc_7: 1.0000 - val_f1_score: 1.0000 - val_loss: 0.0017 - val_mcc: 1.0000 - val_precision_7: 1.0000 - val_recall_7: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 2.3915e-04
# Epoch 21/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9993 - auc_7: 0.9999 - f1_score: 0.9992 - loss: 0.0135 - mcc: 0.9992 - precision_7: 0.9993 - recall_7: 0.9991 - sensitivity: 0.9991 - specificity: 1.0000 - val_accuracy: 0.9284 - val_auc_7: 0.9889 - val_f1_score: 0.9311 - val_loss: 0.3550 - val_mcc: 0.9300 - val_precision_7: 0.9451 - val_recall_7: 0.9185 - val_sensitivity: 0.9185 - val_specificity: 0.9988 - learning_rate: 2.1523e-04
# Epoch 22/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 105us/step - accuracy: 1.0000 - auc_7: 1.0000 - f1_score: 1.0000 - loss: 0.0163 - mcc: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 0.8000 - val_auc_7: 0.9953 - val_f1_score: 0.8000 - val_loss: 1.0065 - val_mcc: 0.7953 - val_precision_7: 0.8000 - val_recall_7: 0.8000 - val_sensitivity: 0.8000 - val_specificity: 0.9953 - learning_rate: 1.9371e-04
# Epoch 23/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9973 - auc_7: 0.9999 - f1_score: 0.9974 - loss: 0.0151 - mcc: 0.9974 - precision_7: 0.9975 - recall_7: 0.9973 - sensitivity: 0.9974 - specificity: 0.9999 - val_accuracy: 0.9228 - val_auc_7: 0.9882 - val_f1_score: 0.9266 - val_loss: 0.3558 - val_mcc: 0.9253 - val_precision_7: 0.9369 - val_recall_7: 0.9171 - val_sensitivity: 0.9171 - val_specificity: 0.9986 - learning_rate: 1.7434e-04
# Epoch 24/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 0s 107us/step - accuracy: 1.0000 - auc_7: 1.0000 - f1_score: 1.0000 - loss: 0.0048 - mcc: 1.0000 - precision_7: 1.0000 - recall_7: 1.0000 - sensitivity: 1.0000 - specificity: 1.0000 - val_accuracy: 1.0000 - val_auc_7: 1.0000 - val_f1_score: 1.0000 - val_loss: 7.1006e-04 - val_mcc: 1.0000 - val_precision_7: 1.0000 - val_recall_7: 1.0000 - val_sensitivity: 1.0000 - val_specificity: 1.0000 - learning_rate: 1.5691e-04
# Epoch 25/25
# 358/358 ━━━━━━━━━━━━━━━━━━━━ 12s 32ms/step - accuracy: 0.9962 - auc_7: 1.0000 - f1_score: 0.9931 - loss: 0.0181 - mcc: 0.9929 - precision_7: 0.9963 - recall_7: 0.9954 - sensitivity: 0.9926 - specificity: 0.9999 - val_accuracy: 0.9242 - val_auc_7: 0.9874 - val_f1_score: 0.9276 - val_loss: 0.3485 - val_mcc: 0.9263 - val_precision_7: 0.9357 - val_recall_7: 0.9199 - val_sensitivity: 0.9199 - val_specificity: 0.9985 - learning_rate: 1.4121e-04

# %%
execution_time_parts = []
avg_time_parts = []

for unit in [(3600, 'hours'), (60, 'minutes'), (1, 'seconds'), (0.001, 'milliseconds')]:
    total_value = int(time_callback.total_train_time // unit[0])
    avg_value = int(np.mean(time_callback.epoch_times) // unit[0])

    if total_value > 0 or unit[0] == 0.001:
        execution_time_parts.append((total_value, unit[1]))
    if avg_value > 0 or unit[0] == 0.001:
        avg_time_parts.append((avg_value, unit[1]))

    time_callback.total_train_time -= total_value * unit[0]
    time_callback.epoch_times = [time - avg_value * unit[0] for time in time_callback.epoch_times]

execution_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in execution_time_parts if value > 0
])

avg_time_string = ", ".join([
    f"{value:02d} {unit_str}" for value, unit_str in avg_time_parts if value > 0
])

print(f"Model training took {execution_time_string}")
print(f"Average time per epoch: {avg_time_string}")
# Out:
# Model training took 02 minutes, 58 seconds, 141 milliseconds
# Average time per epoch: 07 seconds, 106 milliseconds

# %%
_ = model.evaluate(test_gen, steps = test_steps)
# Out:
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9427 - auc_7: 0.9920 - f1_score: 0.9449 - loss: 0.2225 - mcc: 0.9441 - precision_7: 0.9582 - recall_7: 0.9341 - sensitivity: 0.9341 - specificity: 0.9991

# %%
def plot_metrics(hist, metric_name_list):
    """
    Plots the given metrics for the training and validation sets.

    Args:
        hist: a Keras History object containing the training history
        metric_name_list: a list of strings representing the names of the metrics to plot

    Returns:
        None
    """
    num_metrics = len(metric_name_list)

    figure, axes = plt.subplots(num_metrics, figsize=(10, 6 * num_metrics))

    rng = range(1, len(hist.history[metric_name_list[0]]) + 1)

    for ax, metric_n in zip(axes, metric_name_list):
        metric = hist.history[metric_n]
        v_metric = hist.history[f"val_{metric_n}"]

        ax.plot(rng, metric, label=metric_n)
        ax.plot(rng, v_metric, label=f"val_{metric_n}")
        ax.legend()
        ax.set_xlabel("Epochs")

        if metric_n in ("auc", "mcc"):
            ax.set_ylabel(metric_n.upper())
            ax.set_title(metric_n.upper() + " vs Epochs")
        else:
            ax.set_ylabel(metric_n.capitalize())
            ax.set_title(metric_n.capitalize() + " vs Epochs")

        max_loss = max(max(metric), max(v_metric))
        min_loss = min(min(metric), min(v_metric))
        y_max = math.ceil(max_loss)

        if min_loss > 0 or max_loss > 1:
            ax.set_ylim(0, y_max)
        else:
            ax.set_ylim(min_loss, y_max)

        ax.grid(True, linestyle='--', alpha=0.5)
        ax.set_xlim(1, len(metric))

    plt.tight_layout()

    plt.show()

# %%
metric_names = ["loss", "accuracy","f1_score",
                "specificity", "sensitivity", "mcc"]
plot_metrics(history, metric_names)

# %%
def generate_classification_report(model, test_generator, test_steps, batch_size, target_names):
    """
    Generate a classification report, accuracy, and number of errors for a given model and test generator.

    Args:
        model (object): The trained model.
        test_generator (object): The test data generator.
        test_steps (int): The number of steps to iterate over the test generator.
        batch_size (int): The batch size for generating predictions.
        target_names (list): List of target class names for the classification report.

    Returns:
        tuple: A tuple containing true labels, predicted labels, and the classification report.
    """
    predicted_labels = []
    true_labels = []

    for i in range(test_steps):
        batch_data, batch_true_labels = next(test_generator)

        batch_predicted_labels = model.predict_on_batch(batch_data)
        batch_predicted_labels = np.argmax(batch_predicted_labels, axis=1)

        predicted_labels.extend(batch_predicted_labels)
        true_labels.extend(batch_true_labels)

    true_labels = np.array(true_labels)

    if len(true_labels[0]) > 1:
        true_labels = np.argmax(true_labels, axis=1)

    report = classification_report(
        true_labels,
        predicted_labels,
        target_names=target_names,
        digits=4,
        zero_division=1
    )

    accuracy = accuracy_score(true_labels, predicted_labels)
    num_errors = np.sum(true_labels != predicted_labels)

    print(report)
    print(f'There were {num_errors} errors in {len(predicted_labels)} tests for an accuracy of {accuracy*100:6.2f}')

    return true_labels, predicted_labels

# %%
true_labels, predicted_labels = generate_classification_report(
    model, test_gen, test_steps, BATCH_SIZE, df["label"].unique()
)
# Out:
#                         precision    recall  f1-score   support
#
#         Astrocitoma T1     0.9706    0.9429    0.9565        35
#       Astrocitoma T1C+     0.9583    1.0000    0.9787        46
#         Astrocitoma T2     0.9714    1.0000    0.9855        34
#           Carcinoma T1     1.0000    1.0000    1.0000        13
#         Carcinoma T1C+     1.0000    1.0000    1.0000        22
#           Carcinoma T2     1.0000    1.0000    1.0000        15
#          Ependimoma T1     1.0000    0.7778    0.8750         9
#        Ependimoma T1C+     0.8182    0.9000    0.8571        10
#          Ependimoma T2     0.9091    0.9091    0.9091        11
#       Ganglioglioma T1     1.0000    1.0000    1.0000         4
#     Ganglioglioma T1C+     0.7500    1.0000    0.8571         3
#       Ganglioglioma T2     1.0000    0.4000    0.5714         5
#           Germinoma T1     1.0000    1.0000    1.0000         5
#         Germinoma T1C+     0.8750    0.8750    0.8750         8
#           Germinoma T2     1.0000    0.5714    0.7273         7
#        Glioblastoma T1     1.0000    0.9091    0.9524        11
#      Glioblastoma T1C+     0.9048    1.0000    0.9500        19
#        Glioblastoma T2     0.9000    0.8182    0.8571        11
#           Granuloma T1     1.0000    0.6667    0.8000         6
#         Granuloma T1C+     1.0000    0.8333    0.9091         6
#           Granuloma T2     1.0000    0.3333    0.5000         3
#      Meduloblastoma T1     1.0000    1.0000    1.0000         4
#    Meduloblastoma T1C+     1.0000    1.0000    1.0000        13
#      Meduloblastoma T2     1.0000    1.0000    1.0000         8
#          Meningioma T1     0.9623    0.9444    0.9533        54
#        Meningioma T1C+     0.9481    0.9865    0.9669        74
#          Meningioma T2     0.9348    0.9149    0.9247        47
#         Neurocitoma T1     0.9615    0.9615    0.9615        26
#       Neurocitoma T1C+     0.9783    1.0000    0.9890        45
#         Neurocitoma T2     0.8750    1.0000    0.9333        21
#   Oligodendroglioma T1     1.0000    1.0000    1.0000        17
# Oligodendroglioma T1C+     1.0000    1.0000    1.0000        14
#   Oligodendroglioma T2     1.0000    1.0000    1.0000        13
#            Papiloma T1     0.9286    1.0000    0.9630        13
#          Papiloma T1C+     1.0000    0.9545    0.9767        22
#            Papiloma T2     0.8667    1.0000    0.9286        13
#          Schwannoma T1     0.9667    0.9667    0.9667        30
#        Schwannoma T1C+     0.9474    0.9231    0.9351        39
#          Schwannoma T2     0.9600    0.9600    0.9600        25
#         Tuberculoma T1     1.0000    1.0000    1.0000         6
#       Tuberculoma T1C+     0.9444    1.0000    0.9714        17
#         Tuberculoma T2     1.0000    0.5714    0.7273         7
#             _NORMAL T1     1.0000    1.0000    1.0000        50
#             _NORMAL T2     0.9153    1.0000    0.9558        54
#
#               accuracy                         0.9564       895
#              macro avg     0.9601    0.9118    0.9244       895
#           weighted avg     0.9585    0.9564    0.9542       895
#
# There were 39 errors in 895 tests for an accuracy of  95.64

# %%
def confusion_matrix(true_labels, predicted_labels, num_classes):
    """
    Compute the confusion matrix.

    Args:
        true_labels (list or numpy.ndarray): Array-like object of true labels.
        predicted_labels (list or numpy.ndarray): Array-like object of predicted labels.
        num_classes (int): Number of classes.

    Returns:
        numpy.ndarray: Confusion matrix.
    """
    cm = np.zeros((num_classes, num_classes), dtype=int)
    np.add.at(cm, (true_labels, predicted_labels), 1)
    return cm

# %%
cm = confusion_matrix(true_labels, predicted_labels, num_classes)

plt.figure(figsize=(15, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels= df["label"].unique(), yticklabels= df["label"].unique())

plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
